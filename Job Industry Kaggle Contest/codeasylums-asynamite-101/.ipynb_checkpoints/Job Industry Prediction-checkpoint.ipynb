# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
train = pd.read_csv('trainData.csv')
train.head()
# Out:
#    Id                                     company  \
# 0   1                            MM Media Pvt Ltd
# 1   2                          find live infotech
# 2   3         Softtech Career Infosystem Pvt. Ltd
# 3   4                      Onboard HRServices LLP
# 4   5  Spire Technologies and Solutions Pvt. Ltd.
#
#                                            education   experience  \
# 0  UG: B.Tech/B.E. - Any Specialization PG:Any Po...    0 - 1 yrs
# 1  UG: B.Tech/B.E. - Any Specialization PG:MBA/PG...    0 - 0 yrs
# 2  UG: Any Graduate - Any Specialization PG:Any P...    4 - 8 yrs
# 3  UG: Any Graduate - Any Specialization PG:CA Do...  11 - 15 yrs
# 4  UG: B.Tech/B.E. - Any Specialization PG:Any Po...    6 - 8 yrs
#
#                                       jobdescription         jobid  \
# 0  Job Description   Send me Jobs like this Quali...  2.110000e+11
# 1  Job Description   Send me Jobs like this Quali...  2.110000e+11
# 2  Job Description   Send me Jobs like this - as ...  1.010000e+11
# 3  Job Description   Send me Jobs like this - Inv...  8.101690e+10
# 4  Job Description   Send me Jobs like this Pleas...  1.210000e+11
#
#                                  joblocation_address  \
# 0                                            Chennai
# 1                                            Chennai
# 2                                          Bengaluru
# 3  Mumbai, Bengaluru, Kolkata, Chennai, Coimbator...
# 4                                          Bengaluru
#
#                                    jobtitle  numberofpositions  \
# 0  Walkin Data Entry Operator (night Shift)                NaN
# 1        Work Based Onhome Based Part Time.               60.0
# 2                    Pl/sql Developer - SQL                NaN
# 3    Manager/ad/partner - Indirect Tax - CA                NaN
# 4           JAVA Technical Lead (6-8 yrs) -                4.0
#
#                           payrate                   postdate  \
# 0         1,50,000 - 2,25,000 P.A  2016-05-21 19:30:00 +0000
# 1  1,50,000 - 2,50,000 P.A. 20000  2016-05-21 19:30:00 +0000
# 2      Not Disclosed by Recruiter  2016-10-13 16:20:55 +0000
# 3      Not Disclosed by Recruiter  2016-10-13 16:20:55 +0000
# 4      Not Disclosed by Recruiter  2016-10-13 16:20:55 +0000
#
#                                   skills  \
# 0                                   ITES
# 1                              Marketing
# 2  IT Software - Application Programming
# 3                               Accounts
# 4  IT Software - Application Programming
#
#                                    industry
# 0          Media / Entertainment / Internet
# 1  Advertising / PR / MR / Event Management
# 2           IT-Software / Software Services
# 3    Banking / Financial Services / Broking
# 4           IT-Software / Software Services

# %%
print('Length:',len(train)) 
print(train.count())
# Out:
# Length: 19422
# Id                     19422
# company                19419
# education              18198
# experience             19419
# jobdescription         19419
# jobid                  19422
# joblocation_address    18922
# jobtitle               19422
# numberofpositions       3784
# payrate                19370
# postdate               19403
# skills                 18955
# industry               19418
# dtype: int64

# %%
train.isnull().sum()
# Out:
# Id                         0
# company                    3
# education               1224
# experience                 3
# jobdescription             3
# jobid                      0
# joblocation_address      500
# jobtitle                   0
# numberofpositions      15638
# payrate                   52
# postdate                  19
# skills                   467
# industry                   4
# dtype: int64

# %%
train['skills'].value_counts()
# Out:
# IT Software - Application Programming      5387
# Sales                                      2617
# ITES                                       1431
# HR                                          842
# Marketing                                   811
# Accounts                                    766
# Teaching                                    597
# Production                                  594
# Medical                                     382
# Financial Services                          360
# IT Software - Other                         360
# Engineering Design                          336
# IT Software - Network Administration        324
# IT Software - eCommerce                     321
# IT Software - QA & Testing                  315
# IT Software - ERP                           309
# Site Engineering                            297
# Journalism                                  245
# IT Software - DBA                           242
# IT Software - Embedded                      236
# Design                                      217
# IT Hardware                                 216
# Supply Chain                                208
# IT Software - Mobile                        180
# Analytics & Business Intelligence           174
# IT Software - System Programming            155
# Executive Assistant                         155
# Hotels                                      152
# IT Software - Telecom Software              104
# Travel                                       83
# Legal                                        72
# Strategy                                     70
# Top Management                               68
# Fashion Designing                            57
# Architecture                                 55
# IT Software - Client/Server Programming      53
# Export                                       45
# IT Software - Systems                        41
# IT Software - Middleware                     21
# TV                                           20
# Defence Forces                               13
# IT Software - Mainframe                      12
# Packaging                                     8
# Beauty/Fitness/Spa Services                   3
# Shipping                                      1
# Name: skills, dtype: int64

# %%
train['industry'].value_counts()
# Out:
# IT-Software / Software Services           8363
# BPO / Call Centre / ITES                  1095
# Banking / Financial Services / Broking    1083
# Recruitment / Staffing                    1029
# Education / Teaching / Training            811
#                                           ...
# Medical Devices / Equipments                 4
# Brewery / Distillery                         3
# Pulp and Paper                               2
# Broadcasting                                 1
# Leather                                      1
# Name: industry, Length: 63, dtype: int64

# %%
x = train[['skills']]
y = train[['industry']]

# %%
x.size, y.size
# Out:
# (19422, 19422)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (15537, 1)
# (3885, 1)
# (15537, 1)
# (3885, 1)

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn = KNeighborsClassifier(n_neighbors=5,metric='minkowski',p=2)

# %%
x_train.head()
# Out:
#                                       skills
# 5350                    IT Software - Mobile
# 11420                                     HR
# 11511                                   ITES
# 6700   IT Software - Application Programming
# 3002       Analytics & Business Intelligence

# %%
y_train.head()
# Out:
#                                      industry
# 5350          IT-Software / Software Services
# 11420                  Recruitment / Staffing
# 11511                BPO / Call Centre / ITES
# 6700          IT-Software / Software Services
# 3002   Banking / Financial Services / Broking

# %%
print(x_train.shape, y_train.shape)
# Out:
# (15537, 1) (15537, 1)

# %%
job_skills = {}

# %%
skill_industry = train[['skills','industry']]
skill_industry
# Out:
#                                       skills  \
# 0                                       ITES
# 1                                  Marketing
# 2      IT Software - Application Programming
# 3                                   Accounts
# 4      IT Software - Application Programming
# ...                                      ...
# 19417             IT Software - QA & Testing
# 19418  IT Software - Application Programming
# 19419  IT Software - Application Programming
# 19420  IT Software - Application Programming
# 19421       IT Software - System Programming
#
#                                        industry
# 0              Media / Entertainment / Internet
# 1      Advertising / PR / MR / Event Management
# 2               IT-Software / Software Services
# 3        Banking / Financial Services / Broking
# 4               IT-Software / Software Services
# ...                                         ...
# 19417    Banking / Financial Services / Broking
# 19418           IT-Software / Software Services
# 19419                      Internet / Ecommerce
# 19420           IT-Software / Software Services
# 19421           IT-Software / Software Services
#
# [19422 rows x 2 columns]

# %%
for i in range(len(skill_industry)):
    job_skills[skill_industry.loc[i,'skills']] = skill_industry.loc[i,'industry']

# %%
print(len(job_skills), len(skill_industry['skills'].unique()))
# Out:
# 46 46

# %%
print(job_skills)
# Out:
# {'ITES': 'Internet / Ecommerce', 'Marketing': 'Internet / Ecommerce', 'IT Software - Application Programming': 'IT-Software / Software Services', 'Accounts': 'Internet / Ecommerce', 'Production': 'Automobile / Auto Anciliary / Auto Components', 'Sales': 'Industrial Products / Heavy Machinery', 'IT Software - Other': 'IT-Software / Software Services', 'Executive Assistant': 'Oil and Gas / Energy / Power / Infrastructure', 'IT Software - Mobile': 'Internet / Ecommerce', 'Engineering Design': 'FMCG / Foods / Beverage', 'Financial Services': 'KPO / Research / Analytics', 'Hotels': 'Travel / Hotels / Restaurants / Airlines / Railways', 'IT Software - QA & Testing': 'Banking / Financial Services / Broking', 'HR': 'IT-Software / Software Services', 'Supply Chain': 'FMCG / Foods / Beverage', 'IT Software - Network Administration': 'IT-Software / Software Services', 'Architecture': 'Architecture / Interior Design', 'Legal': 'Fertilizers / Pesticides', 'Site Engineering': 'IT-Software / Software Services', 'Journalism': 'Internet / Ecommerce', nan: 'Pharma / Biotech / Clinical Research', 'IT Software - DBA': 'IT-Software / Software Services', 'Strategy': 'Strategy / Management Consulting Firms', 'Medical': 'Pharma / Biotech / Clinical Research', 'Design': 'Internet / Ecommerce', 'Defence Forces': 'Real Estate / Property', 'IT Software - Mainframe': 'IT-Software / Software Services', 'IT Software - Telecom Software': 'IT-Hardware & Networking', 'IT Software - Embedded': 'Semiconductors / Electronics', 'IT Software - Middleware': 'IT-Software / Software Services', 'Teaching': 'Education / Teaching / Training', 'IT Software - System Programming': 'IT-Software / Software Services', 'IT Software - Client/Server Programming': 'IT-Software / Software Services', 'Travel': 'Travel / Hotels / Restaurants / Airlines / Railways', 'IT Software - eCommerce': 'IT-Software / Software Services', 'TV': 'Media / Entertainment / Internet', 'Fashion Designing': 'Textiles / Garments / Accessories', 'IT Software - ERP': 'Recruitment / Staffing', 'IT Hardware': 'Semiconductors / Electronics', 'Analytics & Business Intelligence': 'Internet / Ecommerce', 'Beauty/Fitness/Spa Services': 'Wellness / Fitness / Sports / Beauty', 'Top Management': 'IT-Software / Software Services', 'Export': 'Export / Import', 'IT Software - Systems': 'Recruitment / Staffing', 'Packaging': 'Pharma / Biotech / Clinical Research', 'Shipping': 'Travel / Hotels / Restaurants / Airlines / Railways'}

# %%
sample_submission = pd.read_csv('sample_submission.csv')

# %%
print(sample_submission.head())
# Out:
#       Id                         industry
# 0  19423  IT-Software / Software Services
# 1  19424  IT-Software / Software Services
# 2  19425  IT-Software / Software Services
# 3  19426  IT-Software / Software Services
# 4  19427  IT-Software / Software Services

# %%
test = pd.read_csv('testData.csv')

# %%
print(test.head())
# Out:
#       Id                                            company  \
# 0  19423  Radial HR Solutions hiring for Client of Radia...
# 1  19424                     Hindco Recruitment Consultants
# 2  19425                               Trigent Software Ltd
# 3  19426  Career Trackers and Consulting hiring for A ve...
# 4  19427                                       Confidential
#
#                                            education experience  \
# 0                                                NaN  3 - 8 yrs
# 1              UG: Any Graduate - Any Specialization  4 - 9 yrs
# 2  UG: B.Tech/B.E. - Any Specialization PG:MCA - ...  6 - 8 yrs
# 3  UG: Any Graduate, Graduation Not Required PG:A...  4 - 9 yrs
# 4  UG: Any Graduate - Any Specialization PG:Any P...  3 - 8 yrs
#
#                                       jobdescription         jobid  \
# 0  Job Description   Send me Jobs like this Requi...  2.110000e+11
# 1  Job Description   Send me Jobs like this - To ...  2.810000e+11
# 2  Job Description   Send me Jobs like this Looki...  1.010000e+11
# 3  Job Description   Send me Jobs like this We ha...  1.210000e+11
# 4  Job Description   Send me Jobs like this OpenS...  5.091690e+10
#
#                                  joblocation_address  \
# 0                                          Bengaluru
# 1  Delhi, Mumbai, Ahmedabad, Gurgaon, Bengaluru, ...
# 2                                          Bengaluru
# 3                                          Bengaluru
# 4                                          Bengaluru
#
#                                             jobtitle  numberofpositions  \
# 0                             Inside Sales Executive                NaN
# 1  Activation Manager | Pharmaceutical / FMCG Ind...                NaN
# 2                           Sr. SQL Server Developer                NaN
# 3  Linux Admin / Unix Admin / Linux Unix Administ...                6.0
# 4                 Openstack Development Professional                NaN
#
#                                              payrate  \
# 0                            4,00,000 - 5,00,000 P.A
# 1  This is a part of confidential search. The Com...
# 2                         Not Disclosed by Recruiter
# 3                               Best In The Industry
# 4                         Not Disclosed by Recruiter
#
#                     postdate                                 skills
# 0  2016-10-12 16:21:21 +0000                                  Sales
# 1  2016-10-10 16:21:21 +0000                                  Sales
# 2  2016-10-10 16:21:21 +0000                      IT Software - DBA
# 3  2016-10-12 16:21:21 +0000   IT Software - Network Administration
# 4  2016-10-10 16:21:21 +0000  IT Software - Application Programming

# %%
print(test['skills'].value_counts())
# Out:
# IT Software - Application Programming      602
# Teaching                                   494
# Sales                                      276
# ITES                                       209
# Accounts                                    94
# HR                                          86
# Production                                  73
# Marketing                                   57
# Financial Services                          53
# IT Software - Network Administration        48
# IT Software - Other                         47
# Engineering Design                          46
# IT Software - ERP                           45
# IT Hardware                                 37
# Medical                                     36
# IT Software - DBA                           31
# IT Software - QA & Testing                  27
# IT Software - Embedded                      26
# Site Engineering                            25
# Supply Chain                                24
# IT Software - Mobile                        23
# IT Software - System Programming            21
# Executive Assistant                         17
# Analytics & Business Intelligence           16
# IT Software - eCommerce                     15
# Design                                      10
# IT Software - Telecom Software              10
# Strategy                                    10
# Hotels                                       9
# IT Software - Client/Server Programming      9
# Top Management                               8
# Travel                                       7
# Journalism                                   7
# Legal                                        6
# IT Software - Mainframe                      3
# Export                                       3
# IT Software - Systems                        2
# IT Software - Middleware                     2
# Fashion Designing                            2
# Architecture                                 1
# Name: skills, dtype: int64

# %%
print(len(test['skills'].unique()))
# Out:
# 41

# %%
for i in range(len(test)):
    test.loc[i,'industry'] = job_skills[test.loc[i, 'skills']]

# %%
print(test.head())
# Out:
#       Id                                            company  \
# 0  19423  Radial HR Solutions hiring for Client of Radia...
# 1  19424                     Hindco Recruitment Consultants
# 2  19425                               Trigent Software Ltd
# 3  19426  Career Trackers and Consulting hiring for A ve...
# 4  19427                                       Confidential
#
#                                            education experience  \
# 0                                                NaN  3 - 8 yrs
# 1              UG: Any Graduate - Any Specialization  4 - 9 yrs
# 2  UG: B.Tech/B.E. - Any Specialization PG:MCA - ...  6 - 8 yrs
# 3  UG: Any Graduate, Graduation Not Required PG:A...  4 - 9 yrs
# 4  UG: Any Graduate - Any Specialization PG:Any P...  3 - 8 yrs
#
#                                       jobdescription         jobid  \
# 0  Job Description   Send me Jobs like this Requi...  2.110000e+11
# 1  Job Description   Send me Jobs like this - To ...  2.810000e+11
# 2  Job Description   Send me Jobs like this Looki...  1.010000e+11
# 3  Job Description   Send me Jobs like this We ha...  1.210000e+11
# 4  Job Description   Send me Jobs like this OpenS...  5.091690e+10
#
#                                  joblocation_address  \
# 0                                          Bengaluru
# 1  Delhi, Mumbai, Ahmedabad, Gurgaon, Bengaluru, ...
# 2                                          Bengaluru
# 3                                          Bengaluru
# 4                                          Bengaluru
#
#                                             jobtitle  numberofpositions  \
# 0                             Inside Sales Executive                NaN
# 1  Activation Manager | Pharmaceutical / FMCG Ind...                NaN
# 2                           Sr. SQL Server Developer                NaN
# 3  Linux Admin / Unix Admin / Linux Unix Administ...                6.0
# 4                 Openstack Development Professional                NaN
#
#                                              payrate  \
# 0                            4,00,000 - 5,00,000 P.A
# 1  This is a part of confidential search. The Com...
# 2                         Not Disclosed by Recruiter
# 3                               Best In The Industry
# 4                         Not Disclosed by Recruiter
#
#                     postdate                                 skills  \
# 0  2016-10-12 16:21:21 +0000                                  Sales
# 1  2016-10-10 16:21:21 +0000                                  Sales
# 2  2016-10-10 16:21:21 +0000                      IT Software - DBA
# 3  2016-10-12 16:21:21 +0000   IT Software - Network Administration
# 4  2016-10-10 16:21:21 +0000  IT Software - Application Programming
#
#                                 industry
# 0  Industrial Products / Heavy Machinery
# 1  Industrial Products / Heavy Machinery
# 2        IT-Software / Software Services
# 3        IT-Software / Software Services
# 4        IT-Software / Software Services

# %%
test[['Id','industry']].to_csv('test_submission.csv', index=False)

# %%
from collections import defaultdict 
test_dict = defaultdict(list)

# %%
for i in range(len(test)):
    if test.loc[i, 'skills'] in test_dict:
        test_dict[test.loc[i, 'skills']].append(job_skills[test.loc[i, 'skills']])
    else:
        test_dict[test.loc[i, 'skills']] = []
        test_dict[test.loc[i, 'skills']].append(job_skills[test.loc[i, 'skills']])

# %%
print(len(test_dict))
# Out:
# 41

# %%
unique_dict = defaultdict(list)
for key,value in test_dict.items():
    unique_dict[value[0]].append(key)

# %%
print(len(unique_dict))
print(unique_dict)
# Out:
# 19
# defaultdict(<class 'list'>, {'Industrial Products / Heavy Machinery': ['Sales'], 'IT-Software / Software Services': ['IT Software - DBA', 'IT Software - Network Administration', 'IT Software - Application Programming', 'HR', 'IT Software - Mainframe', 'IT Software - Client/Server Programming', 'IT Software - Other', 'IT Software - eCommerce', 'IT Software - System Programming', 'IT Software - Middleware', 'Site Engineering', 'Top Management'], 'Internet / Ecommerce': ['ITES', 'Marketing', 'Accounts', 'Analytics & Business Intelligence', 'IT Software - Mobile', 'Journalism', 'Design'], 'Pharma / Biotech / Clinical Research': ['Medical', nan], 'Semiconductors / Electronics': ['IT Software - Embedded', 'IT Hardware'], 'Banking / Financial Services / Broking': ['IT Software - QA & Testing'], 'Automobile / Auto Anciliary / Auto Components': ['Production'], 'KPO / Research / Analytics': ['Financial Services'], 'Recruitment / Staffing': ['IT Software - ERP', 'IT Software - Systems'], 'Travel / Hotels / Restaurants / Airlines / Railways': ['Hotels', 'Travel'], 'Oil and Gas / Energy / Power / Infrastructure': ['Executive Assistant'], 'Strategy / Management Consulting Firms': ['Strategy'], 'FMCG / Foods / Beverage': ['Engineering Design', 'Supply Chain'], 'Education / Teaching / Training': ['Teaching'], 'IT-Hardware & Networking': ['IT Software - Telecom Software'], 'Fertilizers / Pesticides': ['Legal'], 'Textiles / Garments / Accessories': ['Fashion Designing'], 'Export / Import': ['Export'], 'Architecture / Interior Design': ['Architecture']})

# %%
test_dict
# Out:
# defaultdict(list,
#             {'Sales': ['Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery',
#               'Industrial Products / Heavy Machinery'],
#              'IT Software - DBA': ['IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services'],
#              'IT Software - Network Administration': ['IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services'],
#              'IT Software - Application Programming': ['IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
# ...
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training'],
#              'Design': ['Internet / Ecommerce',
#               'Internet / Ecommerce',
#               'Internet / Ecommerce',
#               'Internet / Ecommerce',
#               'Internet / Ecommerce',
#               'Internet / Ecommerce',
#               'Internet / Ecommerce',
#               'Internet / Ecommerce',
#               'Internet / Ecommerce',
#               'Internet / Ecommerce'],
#              'Travel': ['Travel / Hotels / Restaurants / Airlines / Railways',
#               'Travel / Hotels / Restaurants / Airlines / Railways',
#               'Travel / Hotels / Restaurants / Airlines / Railways',
#               'Travel / Hotels / Restaurants / Airlines / Railways',
#               'Travel / Hotels / Restaurants / Airlines / Railways',
#               'Travel / Hotels / Restaurants / Airlines / Railways',
#               'Travel / Hotels / Restaurants / Airlines / Railways'],
#              'IT Software - Middleware': ['IT-Software / Software Services',
#               'IT-Software / Software Services'],
#              'Site Engineering': ['IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services'],
#              'Top Management': ['IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services'],
#              'Supply Chain': ['FMCG / Foods / Beverage',
#               'FMCG / Foods / Beverage',
#               'FMCG / Foods / Beverage',
#               'FMCG / Foods / Beverage',
#               'FMCG / Foods / Beverage',
#               'FMCG / Foods / Beverage',
#               'FMCG / Foods / Beverage',
#               'FMCG / Foods / Beverage',
#               'FMCG / Foods / Beverage',
#               'FMCG / Foods / Beverage',
#               'FMCG / Foods / Beverage',
#               'FMCG / Foods / Beverage',
#               'FMCG / Foods / Beverage',
#               'FMCG / Foods / Beverage',
#               'FMCG / Foods / Beverage',
#               'FMCG / Foods / Beverage',
#               'FMCG / Foods / Beverage',
#               'FMCG / Foods / Beverage',
#               'FMCG / Foods / Beverage',
#               'FMCG / Foods / Beverage',
#               'FMCG / Foods / Beverage',
#               'FMCG / Foods / Beverage',
#               'FMCG / Foods / Beverage',
#               'FMCG / Foods / Beverage'],
#              'IT Software - Telecom Software': ['IT-Hardware & Networking',
#               'IT-Hardware & Networking',
#               'IT-Hardware & Networking',
#               'IT-Hardware & Networking',
#               'IT-Hardware & Networking',
#               'IT-Hardware & Networking',
#               'IT-Hardware & Networking',
#               'IT-Hardware & Networking',
#               'IT-Hardware & Networking',
#               'IT-Hardware & Networking'],
#              'Legal': ['Fertilizers / Pesticides',
#               'Fertilizers / Pesticides',
#               'Fertilizers / Pesticides',
#               'Fertilizers / Pesticides',
#               'Fertilizers / Pesticides',
#               'Fertilizers / Pesticides'],
#              'Fashion Designing': ['Textiles / Garments / Accessories',
#               'Textiles / Garments / Accessories'],
#              'Export': ['Export / Import',
#               'Export / Import',
#               'Export / Import'],
#              'IT Software - Systems': ['Recruitment / Staffing',
#               'Recruitment / Staffing'],
#              'Architecture': ['Architecture / Interior Design']})

# %%
test.isnull().sum()
# Out:
# Id                        0
# company                   0
# education               771
# experience                0
# jobdescription            0
# jobid                     0
# joblocation_address       0
# jobtitle                  0
# numberofpositions      1897
# payrate                  44
# postdate                  3
# skills                   60
# industry                  0
# dtype: int64

# %%
train['skills'].value_counts()
# Out:
# IT Software - Application Programming      5387
# Sales                                      2617
# ITES                                       1431
# HR                                          842
# Marketing                                   811
# Accounts                                    766
# Teaching                                    597
# Production                                  594
# Medical                                     382
# Financial Services                          360
# IT Software - Other                         360
# Engineering Design                          336
# IT Software - Network Administration        324
# IT Software - eCommerce                     321
# IT Software - QA & Testing                  315
# IT Software - ERP                           309
# Site Engineering                            297
# Journalism                                  245
# IT Software - DBA                           242
# IT Software - Embedded                      236
# Design                                      217
# IT Hardware                                 216
# Supply Chain                                208
# IT Software - Mobile                        180
# Analytics & Business Intelligence           174
# IT Software - System Programming            155
# Executive Assistant                         155
# Hotels                                      152
# IT Software - Telecom Software              104
# Travel                                       83
# Legal                                        72
# Strategy                                     70
# Top Management                               68
# Fashion Designing                            57
# Architecture                                 55
# IT Software - Client/Server Programming      53
# Export                                       45
# IT Software - Systems                        41
# IT Software - Middleware                     21
# TV                                           20
# Defence Forces                               13
# IT Software - Mainframe                      12
# Packaging                                     8
# Beauty/Fitness/Spa Services                   3
# Shipping                                      1
# Name: skills, dtype: int64

# %%
skill_industry_count = defaultdict(list)

# %%
for i in range(len(skill_industry)):
    skill_industry_count[skill_industry.loc[i,'skills']].append(skill_industry.loc[i,'industry'])

# %%
skill_industry_unique_count = {}
for key,value in skill_industry_count.items():
    skill_industry_unique_count[key] = len(set(value))

# %%
skill_industry_unique_count
# Out:
# {'ITES': 40,
#  'Marketing': 44,
#  'IT Software - Application Programming': 44,
#  'Accounts': 48,
#  'Production': 41,
#  'Sales': 58,
#  'IT Software - Other': 24,
#  'Executive Assistant': 39,
#  'IT Software - Mobile': 11,
#  'Engineering Design': 38,
#  'Financial Services': 22,
#  'Hotels': 17,
#  'IT Software - QA & Testing': 23,
#  'HR': 44,
#  'Supply Chain': 36,
#  'IT Software - Network Administration': 21,
#  'Architecture': 12,
#  'Legal': 22,
#  'Site Engineering': 35,
#  'Journalism': 24,
#  nan: 47,
#  'IT Software - DBA': 13,
#  'Strategy': 21,
#  'Medical': 22,
#  'Design': 27,
#  'Defence Forces': 7,
#  'IT Software - Mainframe': 2,
#  'IT Software - Telecom Software': 8,
#  'IT Software - Embedded': 16,
#  'IT Software - Middleware': 4,
#  'Teaching': 23,
#  'IT Software - System Programming': 19,
#  'IT Software - Client/Server Programming': 8,
#  'Travel': 7,
#  'IT Software - eCommerce': 17,
#  'TV': 8,
#  'Fashion Designing': 8,
#  'IT Software - ERP': 20,
#  'IT Hardware': 21,
#  'Analytics & Business Intelligence': 29,
#  'Beauty/Fitness/Spa Services': 1,
#  'Top Management': 28,
#  'Export': 15,
#  'IT Software - Systems': 9,
#  'Packaging': 4,
#  'Shipping': 1}

# %%
skill_industry_count
# Out:
# defaultdict(list,
#             {'ITES': ['Media / Entertainment / Internet',
#               'IT-Software / Software Services',
#               'Recruitment / Staffing',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'BPO / Call Centre / ITES',
#               'Banking / Financial Services / Broking',
#               'Internet / Ecommerce',
#               'Internet / Ecommerce',
#               'Recruitment / Staffing',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'Medical / Healthcare / Hospitals',
#               'Medical / Healthcare / Hospitals',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'NGO / Social Services / Regulators / Industry Associations',
#               'Real Estate / Property',
#               'BPO / Call Centre / ITES',
#               'Education / Teaching / Training',
#               'BPO / Call Centre / ITES',
#               'Courier / Transportation / Freight / Warehousing',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'Recruitment / Staffing',
#               'BPO / Call Centre / ITES',
#               'IT-Software / Software Services',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'Automobile / Auto Anciliary / Auto Components',
#               'Recruitment / Staffing',
#               'Medical / Healthcare / Hospitals',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'BPO / Call Centre / ITES',
#               'IT-Hardware & Networking',
#               'BPO / Call Centre / ITES',
#               'IT-Software / Software Services',
#               'BPO / Call Centre / ITES',
#               'Banking / Financial Services / Broking',
#               'Recruitment / Staffing',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'Recruitment / Staffing',
#               'BPO / Call Centre / ITES',
#               'IT-Software / Software Services',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'Courier / Transportation / Freight / Warehousing',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'Pharma / Biotech / Clinical Research',
#               'BPO / Call Centre / ITES',
#               'Recruitment / Staffing',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'Medical / Healthcare / Hospitals',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'Medical / Healthcare / Hospitals',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'Pharma / Biotech / Clinical Research',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'Pharma / Biotech / Clinical Research',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'Gems / Jewellery',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'IT-Software / Software Services',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'Publishing',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'Medical / Healthcare / Hospitals',
#               'BPO / Call Centre / ITES',
#               'Recruitment / Staffing',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'IT-Software / Software Services',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'Internet / Ecommerce',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'Travel / Hotels / Restaurants / Airlines / Railways',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'Pharma / Biotech / Clinical Research',
#               'KPO / Research / Analytics',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'IT-Software / Software Services',
#               'Medical / Healthcare / Hospitals',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'IT-Software / Software Services',
#               'Education / Teaching / Training',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'Medical / Healthcare / Hospitals',
#               'BPO / Call Centre / ITES',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'IT-Software / Software Services',
#               'BPO / Call Centre / ITES',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'Medical / Healthcare / Hospitals',
#               'Pharma / Biotech / Clinical Research',
#               'Education / Teaching / Training',
#               'Education / Teaching / Training',
#               'BPO / Call Centre / ITES',
#               'IT-Software / Software Services',
#               'Internet / Ecommerce',
#               'Pharma / Biotech / Clinical Research',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'Agriculture / Dairy',
#               'BPO / Call Centre / ITES',
#               'Strategy / Management Consulting Firms',
#               'IT-Software / Software Services',
#               'Strategy / Management Consulting Firms',
#               'BPO / Call Centre / ITES',
#               'Internet / Ecommerce',
#               'Banking / Financial Services / Broking',
#               'Internet / Ecommerce',
#               'IT-Software / Software Services',
#               'BPO / Call Centre / ITES',
#               'Education / Teaching / Training',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'Medical / Healthcare / Hospitals',
#               'BPO / Call Centre / ITES',
#               'Internet / Ecommerce',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'Agriculture / Dairy',
#               'BPO / Call Centre / ITES',
#               'KPO / Research / Analytics',
#               'IT-Software / Software Services',
#               'BPO / Call Centre / ITES',
#               'Pharma / Biotech / Clinical Research',
#               'IT-Software / Software Services',
#               'Medical / Healthcare / Hospitals',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'Strategy / Management Consulting Firms',
#               'BPO / Call Centre / ITES',
#               'IT-Software / Software Services',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'IT-Software / Software Services',
#               'Education / Teaching / Training',
#               'BPO / Call Centre / ITES',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'BPO / Call Centre / ITES',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'Education / Teaching / Training',
#               'BPO / Call Centre / ITES',
#               'IT-Software / Software Services',
#               'Insurance',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'IT-Software / Software Services',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'Banking / Financial Services / Broking',
#               'BPO / Call Centre / ITES',
#               'Accounting / Finance',
#               'Real Estate / Property',
#               'IT-Software / Software Services',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'Media / Entertainment / Internet',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'IT-Software / Software Services',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'Banking / Financial Services / Broking',
#               'IT-Hardware & Networking',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'Medical / Healthcare / Hospitals',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'Medical / Healthcare / Hospitals',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'Real Estate / Property',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'IT-Software / Software Services',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'KPO / Research / Analytics',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'Telecom/ISP /',
#               'BPO / Call Centre / ITES',
#               'IT-Software / Software Services',
#               'BPO / Call Centre / ITES',
#               'Banking / Financial Services / Broking',
#               'IT-Software / Software Services',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'IT-Software / Software Services',
#               'Recruitment / Staffing',
#               'BPO / Call Centre / ITES',
#               'Recruitment / Staffing',
#               'IT-Software / Software Services',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'Recruitment / Staffing',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'Recruitment / Staffing',
#               'IT-Software / Software Services',
#               'Internet / Ecommerce',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'Insurance',
#               'Recruitment / Staffing',
#               'Recruitment / Staffing',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'IT-Software / Software Services',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'Medical / Healthcare / Hospitals',
#               'Retail / Wholesale',
#               'IT-Software / Software Services',
#               'Security / Law Enforcement',
#               'Recruitment / Staffing',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'Recruitment / Staffing',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'Automobile / Auto Anciliary / Auto Components',
#               'Banking / Financial Services / Broking',
#               'Recruitment / Staffing',
#               'Recruitment / Staffing',
#               'BPO / Call Centre / ITES',
#               'Telecom/ISP /',
#               'Strategy / Management Consulting Firms',
#               'Medical / Healthcare / Hospitals',
#               'KPO / Research / Analytics',
#               'Internet / Ecommerce',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'IT-Software / Software Services',
#               'BPO / Call Centre / ITES',
#               'IT-Software / Software Services',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'Medical / Healthcare / Hospitals',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'IT-Software / Software Services',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'Recruitment / Staffing',
#               'BPO / Call Centre / ITES',
#               'IT-Software / Software Services',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'KPO / Research / Analytics',
#               'BPO / Call Centre / ITES',
#               'Education / Teaching / Training',
#               'BPO / Call Centre / ITES',
#               'IT-Software / Software Services',
#               'Internet / Ecommerce',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'IT-Software / Software Services',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'Internet / Ecommerce',
#               'Consumer Electronics / Appliances / Durables',
#               'BPO / Call Centre / ITES',
#               'Real Estate / Property',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'IT-Software / Software Services',
#               'Education / Teaching / Training',
#               'Other',
#               'BPO / Call Centre / ITES',
#               'IT-Software / Software Services',
#               'Real Estate / Property',
#               'BPO / Call Centre / ITES',
#               'IT-Software / Software Services',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'Banking / Financial Services / Broking',
#               'BPO / Call Centre / ITES',
#               'IT-Software / Software Services',
#               'BPO / Call Centre / ITES',
#               'IT-Hardware & Networking',
#               'BPO / Call Centre / ITES',
#               'Telecom/ISP /',
#               'IT-Software / Software Services',
#               'BPO / Call Centre / ITES',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'Consumer Electronics / Appliances / Durables',
#               'IT-Software / Software Services',
#               'BPO / Call Centre / ITES',
#               'IT-Software / Software Services',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'Insurance',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'Internet / Ecommerce',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'Consumer Electronics / Appliances / Durables',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'Education / Teaching / Training',
#               'Banking / Financial Services / Broking',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'Real Estate / Property',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'IT-Software / Software Services',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'Banking / Financial Services / Broking',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'KPO / Research / Analytics',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'IT-Software / Software Services',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'Travel / Hotels / Restaurants / Airlines / Railways',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'Travel / Hotels / Restaurants / Airlines / Railways',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'IT-Software / Software Services',
#               'Education / Teaching / Training',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'Education / Teaching / Training',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'Banking / Financial Services / Broking',
#               'BPO / Call Centre / ITES',
#               'Travel / Hotels / Restaurants / Airlines / Railways',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'IT-Software / Software Services',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'Internet / Ecommerce',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'IT-Hardware & Networking',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'Banking / Financial Services / Broking',
#               'Courier / Transportation / Freight / Warehousing',
#               'BPO / Call Centre / ITES',
#               'Internet / Ecommerce',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'Wellness / Fitness / Sports',
#               'BPO / Call Centre / ITES',
#               'IT-Software / Software Services',
#               'BPO / Call Centre / ITES',
#               'Banking / Financial Services / Broking',
#               'IT-Software / Software Services',
#               'Internet / Ecommerce',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'Telecom/ISP /',
#               'Internet / Ecommerce',
#               'BPO / Call Centre / ITES',
#               'IT-Software / Software Services',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'Travel / Hotels / Restaurants / Airlines / Railways',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'Travel / Hotels / Restaurants / Airlines / Railways',
#               'Telecom/ISP /',
#               'BPO / Call Centre / ITES',
#               'Travel / Hotels / Restaurants / Airlines / Railways',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'Travel / Hotels / Restaurants / Airlines / Railways',
#               'Strategy / Management Consulting Firms',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'Office Equipment / Automation',
#               'IT-Software / Software Services',
#               'IT-Hardware & Networking',
#               'IT-Software / Software Services',
#               'Recruitment / Staffing',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'IT-Software / Software Services',
#               'BPO / Call Centre / ITES',
#               'IT-Software / Software Services',
#               'Education / Teaching / Training',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'Internet / Ecommerce',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'Recruitment / Staffing',
#               'Banking / Financial Services / Broking',
#               'BPO / Call Centre / ITES',
#               'IT-Software / Software Services',
#               'BPO / Call Centre / ITES',
#               'Internet / Ecommerce',
#               'BPO / Call Centre / ITES',
#               'Strategy / Management Consulting Firms',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'IT-Software / Software Services',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'IT-Software / Software Services',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'Retail / Wholesale',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'Insurance',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'Banking / Financial Services / Broking',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'Telecom/ISP /',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'Industrial Products / Heavy Machinery',
#               'BPO / Call Centre / ITES',
#               'Banking / Financial Services / Broking',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'Wellness / Fitness / Sports',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'Banking / Financial Services / Broking',
#               'IT-Software / Software Services',
#               'BPO / Call Centre / ITES',
#               'IT-Software / Software Services',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'Recruitment / Staffing',
#               'BPO / Call Centre / ITES',
#               'Medical / Healthcare / Hospitals',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'Consumer Electronics / Appliances / Durables',
#               'Internet / Ecommerce',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'Banking / Financial Services / Broking',
#               'Retail / Wholesale',
#               'IT-Software / Software Services',
#               'BPO / Call Centre / ITES',
#               'Industrial Products / Heavy Machinery',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'Oil and Gas / Energy / Power / Infrastructure',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'Other',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'Internet / Ecommerce',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'Insurance',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'Accounting / Finance',
#               'BPO / Call Centre / ITES',
#               'IT-Software / Software Services',
#               'BPO / Call Centre / ITES',
#               'Accounting / Finance',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'IT-Software / Software Services',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'Travel / Hotels / Restaurants / Airlines / Railways',
#               'Consumer Electronics / Appliances / Durables',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'Courier / Transportation / Freight / Warehousing',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'IT-Software / Software Services',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'IT-Software / Software Services',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'IT-Software / Software Services',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'Banking / Financial Services / Broking',
#               'BPO / Call Centre / ITES',
#               'Medical / Healthcare / Hospitals',
#               'BPO / Call Centre / ITES',
#               'Banking / Financial Services / Broking',
#               'IT-Software / Software Services',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'Strategy / Management Consulting Firms',
#               'IT-Software / Software Services',
#               'Telecom/ISP /',
#               'BPO / Call Centre / ITES',
#               'Banking / Financial Services / Broking',
#               'BPO / Call Centre / ITES',
#               'Accounting / Finance',
#               'BPO / Call Centre / ITES',
#               'Travel / Hotels / Restaurants / Airlines / Railways',
#               'Medical / Healthcare / Hospitals',
#               'IT-Software / Software Services',
#               'BPO / Call Centre / ITES',
#               'Telecom/ISP /',
#               'Telecom/ISP /',
#               'IT-Software / Software Services',
#               'BPO / Call Centre / ITES',
#               'Medical / Healthcare / Hospitals',
#               'IT-Software / Software Services',
#               'Telecom/ISP /',
#               'IT-Software / Software Services',
#               'Telecom/ISP /',
#               'Internet / Ecommerce',
#               'Medical / Healthcare / Hospitals',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'Construction / Engineering / Cement / Metals',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'Medical / Healthcare / Hospitals',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'Accounting / Finance',
#               'IT-Software / Software Services',
#               'Education / Teaching / Training',
#               'Accounting / Finance',
#               'IT-Software / Software Services',
#               'Strategy / Management Consulting Firms',
#               'IT-Software / Software Services',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'IT-Software / Software Services',
#               'Medical / Healthcare / Hospitals',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'Internet / Ecommerce',
#               'BPO / Call Centre / ITES',
#               'IT-Software / Software Services',
#               'Internet / Ecommerce',
#               'Banking / Financial Services / Broking',
#               'Education / Teaching / Training',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'Banking / Financial Services / Broking',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'Telecom/ISP',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'Recruitment / Staffing',
#               'Oil and Gas / Energy / Power / Infrastructure',
#               'Banking / Financial Services / Broking',
#               'Insurance',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'Internet / Ecommerce',
#               'Recruitment / Staffing',
#               'BPO / Call Centre / ITES',
#               'Telecom/ISP',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'BPO / Call Centre / ITES',
#               'Recruitment / Staffing',
#               'Recruitment / Staffing',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'Recruitment / Staffing',
#               'BPO / Call Centre / ITES',
#               'Recruitment / Staffing',
#               'Insurance',
#               'Courier / Transportation / Freight / Warehousing',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'IT-Software / Software Services',
#               'BPO / Call Centre / ITES',
#               'IT-Software / Software Services',
#               'Telecom/ISP',
#               'Construction / Engineering / Cement / Metals',
#               'BPO / Call Centre / ITES',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'Construction / Engineering / Cement / Metals',
#               'IT-Software / Software Services',
#               'KPO / Research / Analytics',
#               'BPO / Call Centre / ITES',
#               'Banking / Financial Services / Broking',
#               'Insurance',
#               'BPO / Call Centre / ITES',
#               'Accounting / Finance',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'Medical / Healthcare / Hospitals',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'IT-Software / Software Services',
#               'BPO / Call Centre / ITES',
#               'Pharma / Biotech / Clinical Research',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'Semiconductors / Electronics',
#               'Medical / Healthcare / Hospitals',
#               'Banking / Financial Services / Broking',
#               'Telecom/ISP /',
#               'Accounting / Finance',
#               'BPO / Call Centre / ITES',
#               'IT-Software / Software Services',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'Telecom/ISP /',
#               'Travel / Hotels / Restaurants / Airlines / Railways',
#               'Other',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'IT-Software / Software Services',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'Medical / Healthcare / Hospitals',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'Banking / Financial Services / Broking',
#               'Insurance',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'Medical / Healthcare / Hospitals',
#               'BPO / Call Centre / ITES',
#               'BPO / Call Centre / ITES',
#               'Banking / Financial Services / Broking',
#               ...],
#              'Marketing': ['Advertising / PR / MR / Event Management',
#               'Insurance',
#               'Pharma / Biotech / Clinical Research',
#               'Medical / Healthcare / Hospitals',
#               'Construction / Engineering / Cement / Metals',
#               'Advertising / PR / MR / Event Management',
#               'Medical / Healthcare / Hospitals',
#               'Construction / Engineering / Cement / Metals',
#               'Industrial Products / Heavy Machinery',
#               'Advertising / PR / MR / Event Management',
#               'Advertising / PR / MR / Event Management',
#               'Pharma / Biotech / Clinical Research',
#               'Advertising / PR / MR / Event Management',
#               'Pharma / Biotech / Clinical Research',
#               'Pharma / Biotech / Clinical Research',
#               'Recruitment / Staffing',
#               'IT-Software / Software Services',
#               'Travel / Hotels / Restaurants / Airlines / Railways',
#               'Advertising / PR / MR / Event Management',
#               'Recruitment / Staffing',
#               'Advertising / PR / MR / Event Management',
#               'Automobile / Auto Anciliary / Auto Components',
#               'Construction / Engineering / Cement / Metals',
#               'Industrial Products / Heavy Machinery',
#               'Advertising / PR / MR / Event Management',
#               'Industrial Products / Heavy Machinery',
#               'IT-Software / Software Services',
#               'Advertising / PR / MR / Event Management',
#               'Advertising / PR / MR / Event Management',
#               'FMCG / Foods / Beverage',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'Agriculture / Dairy',
#               'Internet / Ecommerce',
#               'IT-Hardware & Networking',
#               'Medical / Healthcare / Hospitals',
#               'IT-Software / Software Services',
#               'Medical / Healthcare / Hospitals',
#               'IT-Software / Software Services',
#               'Advertising / PR / MR / Event Management',
#               'Internet / Ecommerce',
#               'Medical / Healthcare / Hospitals',
#               'Advertising / PR / MR / Event Management',
#               'IT-Software / Software Services',
#               'Pharma / Biotech / Clinical Research',
#               'IT-Software / Software Services',
#               'Recruitment / Staffing',
#               'IT-Software / Software Services',
#               'Education / Teaching / Training',
#               'IT-Software / Software Services',
#               'Construction / Engineering / Cement / Metals',
#               'Other',
#               'Printing / Packaging',
#               'Industrial Products / Heavy Machinery',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'KPO / Research / Analytics',
#               'Media / Entertainment / Internet',
#               'IT-Software / Software Services',
#               'FMCG / Foods / Beverage',
#               'FMCG / Foods / Beverage',
#               'Banking / Financial Services / Broking',
#               'BPO / Call Centre / ITES',
#               'Advertising / PR / MR / Event Management',
#               'Architecture / Interior Design',
#               'Internet / Ecommerce',
#               'Internet / Ecommerce',
#               'Automobile / Auto Anciliary / Auto Components',
#               'FMCG / Foods / Beverage',
#               'Retail / Wholesale',
#               'Advertising / PR / MR / Event Management',
#               'Education / Teaching / Training',
#               'Printing / Packaging',
#               'FMCG / Foods / Beverage',
#               'IT-Software / Software Services',
#               'Internet / Ecommerce',
#               'Media / Entertainment / Internet',
#               'Pharma / Biotech / Clinical Research',
# ...
#               'BPO / Call Centre / ITES',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'Banking / Financial Services / Broking',
#               'Banking / Financial Services / Broking',
#               'Banking / Financial Services / Broking',
#               'IT-Software / Software Services',
#               'Accounting / Finance',
#               'Automobile / Auto Anciliary / Auto Components',
#               'BPO / Call Centre / ITES',
#               'Banking / Financial Services / Broking',
#               'Chemicals / PetroChemical / Plastic / Rubber',
#               'Glass / Glassware',
#               'IT-Software / Software Services',
#               'Accounting / Finance',
#               'Recruitment / Staffing',
#               'KPO / Research / Analytics',
#               'Strategy / Management Consulting Firms',
#               'Strategy / Management Consulting Firms',
#               'IT-Software / Software Services',
#               'KPO / Research / Analytics',
#               'Recruitment / Staffing',
#               'Recruitment / Staffing',
#               'KPO / Research / Analytics',
#               'KPO / Research / Analytics',
#               'KPO / Research / Analytics',
#               'Strategy / Management Consulting Firms',
#               'KPO / Research / Analytics',
#               'Strategy / Management Consulting Firms',
#               'Banking / Financial Services / Broking',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'BPO / Call Centre / ITES',
#               'KPO / Research / Analytics',
#               'KPO / Research / Analytics',
#               'IT-Software / Software Services',
#               'BPO / Call Centre / ITES',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'KPO / Research / Analytics',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'Banking / Financial Services / Broking',
#               'IT-Software / Software Services',
#               'Insurance',
#               'Pharma / Biotech / Clinical Research',
#               'IT-Software / Software Services',
#               'Medical / Healthcare / Hospitals',
#               'KPO / Research / Analytics',
#               'Other',
#               'IT-Software / Software Services',
#               'Accounting / Finance',
#               'BPO / Call Centre / ITES',
#               'Industrial Products / Heavy Machinery',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'Industrial Products / Heavy Machinery',
#               'IT-Software / Software Services',
#               'BPO / Call Centre / ITES',
#               'Strategy / Management Consulting Firms',
#               'Courier / Transportation / Freight / Warehousing',
#               'Other',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'KPO / Research / Analytics',
#               'Banking / Financial Services / Broking',
#               'IT-Software / Software Services',
#               'Banking / Financial Services / Broking',
#               'IT-Software / Software Services',
#               'Pharma / Biotech / Clinical Research',
#               'IT-Software / Software Services',
#               'Internet / Ecommerce',
#               'IT-Software / Software Services',
#               'Pharma / Biotech / Clinical Research',
#               'IT-Software / Software Services',
#               'KPO / Research / Analytics',
#               'Pharma / Biotech / Clinical Research',
#               'Telecom/ISP /',
#               'Oil and Gas / Energy / Power / Infrastructure',
#               'IT-Software / Software Services',
#               'Other',
#               'IT-Hardware & Networking',
#               'IT-Software / Software Services',
#               'Banking / Financial Services / Broking',
#               'Banking / Financial Services / Broking',
#               'Banking / Financial Services / Broking',
#               'IT-Hardware & Networking',
#               'Accounting / Finance',
#               'Banking / Financial Services / Broking',
#               'Banking / Financial Services / Broking',
#               'Pharma / Biotech / Clinical Research',
#               'Internet / Ecommerce',
#               'Advertising / PR / MR / Event Management',
#               'Banking / Financial Services / Broking',
#               'KPO / Research / Analytics',
#               'Gems / Jewellery',
#               'Accounting / Finance',
#               'Medical / Healthcare / Hospitals',
#               'Banking / Financial Services / Broking',
#               'Banking / Financial Services / Broking',
#               'BPO / Call Centre / ITES',
#               'Banking / Financial Services / Broking',
#               'IT-Software / Software Services',
#               'KPO / Research / Analytics',
#               'Accounting / Finance',
#               'Banking / Financial Services / Broking',
#               'IT-Software / Software Services',
#               'KPO / Research / Analytics',
#               'IT-Software / Software Services',
#               'Banking / Financial Services / Broking',
#               'Banking / Financial Services / Broking',
#               'Strategy / Management Consulting Firms',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'NGO / Social Services / Regulators / Industry Associations',
#               'IT-Software / Software Services',
#               'KPO / Research / Analytics',
#               'KPO / Research / Analytics',
#               'KPO / Research / Analytics',
#               'KPO / Research / Analytics',
#               'Banking / Financial Services / Broking',
#               'Banking / Financial Services / Broking',
#               'Banking / Financial Services / Broking',
#               'Banking / Financial Services / Broking',
#               'Internet / Ecommerce',
#               'BPO / Call Centre / ITES',
#               'Banking / Financial Services / Broking',
#               'Banking / Financial Services / Broking',
#               'BPO / Call Centre / ITES',
#               'IT-Software / Software Services',
#               'BPO / Call Centre / ITES',
#               'Accounting / Finance',
#               'KPO / Research / Analytics',
#               'FMCG / Foods / Beverage',
#               'Recruitment / Staffing',
#               'Brewery / Distillery',
#               'Aviation / Aerospace Firms',
#               'Retail / Wholesale',
#               'Education / Teaching / Training',
#               'Banking / Financial Services / Broking',
#               'KPO / Research / Analytics',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'Banking / Financial Services / Broking',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'Recruitment / Staffing',
#               'IT-Software / Software Services',
#               'Banking / Financial Services / Broking',
#               'IT-Software / Software Services',
#               'KPO / Research / Analytics',
#               'Internet / Ecommerce',
#               'Real Estate / Property',
#               'Retail / Wholesale',
#               'KPO / Research / Analytics',
#               'KPO / Research / Analytics',
#               'Banking / Financial Services / Broking',
#               'BPO / Call Centre / ITES',
#               'KPO / Research / Analytics',
#               'Internet / Ecommerce',
#               'Internet / Ecommerce'],
#              'Beauty/Fitness/Spa Services': ['Wellness / Fitness / Sports / Beauty',
#               'Wellness / Fitness / Sports / Beauty',
#               'Wellness / Fitness / Sports / Beauty'],
#              'Top Management': ['Banking / Financial Services / Broking',
#               'Medical / Healthcare / Hospitals',
#               'Pharma / Biotech / Clinical Research',
#               'IT-Software / Software Services',
#               'Agriculture / Dairy',
#               'FMCG / Foods / Beverage',
#               'Accounting / Finance',
#               'Recruitment / Staffing',
#               'Recruitment / Staffing',
#               'Recruitment / Staffing',
#               'Recruitment / Staffing',
#               'Recruitment / Staffing',
#               'Recruitment / Staffing',
#               'Other',
#               'Pharma / Biotech / Clinical Research',
#               'Strategy / Management Consulting Firms',
#               'Recruitment / Staffing',
#               'IT-Software / Software Services',
#               'Advertising / PR / MR / Event Management',
#               'Consumer Electronics / Appliances / Durables',
#               'IT-Software / Software Services',
#               'BPO / Call Centre / ITES',
#               'IT-Hardware & Networking',
#               'Printing / Packaging',
#               'KPO / Research / Analytics',
#               'Strategy / Management Consulting Firms',
#               'Oil and Gas / Energy / Power / Infrastructure',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'Oil and Gas / Energy / Power / Infrastructure',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'Strategy / Management Consulting Firms',
#               'IT-Software / Software Services',
#               'Courier / Transportation / Freight / Warehousing',
#               'Industrial Products / Heavy Machinery',
#               'Medical / Healthcare / Hospitals',
#               'IT-Software / Software Services',
#               'Banking / Financial Services / Broking',
#               'Advertising / PR / MR / Event Management',
#               'Travel / Hotels / Restaurants / Airlines / Railways',
#               'IT-Software / Software Services',
#               'Education / Teaching / Training',
#               'Other',
#               'Education / Teaching / Training',
#               'IT-Software / Software Services',
#               'Internet / Ecommerce',
#               'Education / Teaching / Training',
#               'Construction / Engineering / Cement / Metals',
#               'Chemicals / PetroChemical / Plastic / Rubber',
#               'Strategy / Management Consulting Firms',
#               'Banking / Financial Services / Broking',
#               'IT-Software / Software Services',
#               'Other',
#               'Oil and Gas / Energy / Power / Infrastructure',
#               'Construction / Engineering / Cement / Metals',
#               'IT-Software / Software Services',
#               'Industrial Products / Heavy Machinery',
#               'Security / Law Enforcement',
#               'Education / Teaching / Training',
#               'IT-Software / Software Services',
#               'NGO / Social Services / Regulators / Industry Associations',
#               'IT-Software / Software Services',
#               'Medical / Healthcare / Hospitals',
#               'Banking / Financial Services / Broking',
#               'Insurance',
#               'Textiles / Garments / Accessories',
#               'IT-Software / Software Services'],
#              'Export': ['Export / Import',
#               'Automobile / Auto Anciliary / Auto Components',
#               'Export / Import',
#               'FMCG / Foods / Beverage',
#               'FMCG / Foods / Beverage',
#               'Export / Import',
#               'Shipping / Marine',
#               'Recruitment / Staffing',
#               'Other',
#               'Oil and Gas / Energy / Power / Infrastructure',
#               'Export / Import',
#               'Chemicals / PetroChemical / Plastic / Rubber',
#               'Export / Import',
#               'Textiles / Garments / Accessories',
#               'Textiles / Garments / Accessories',
#               'Textiles / Garments / Accessories',
#               'Export / Import',
#               'Textiles / Garments / Accessories',
#               'Internet / Ecommerce',
#               'Export / Import',
#               'Courier / Transportation / Freight / Warehousing',
#               'Textiles / Garments / Accessories',
#               'Pharma / Biotech / Clinical Research',
#               'Recruitment / Staffing',
#               'Textiles / Garments / Accessories',
#               'Retail / Wholesale',
#               'Export / Import',
#               'FMCG / Foods / Beverage',
#               'Export / Import',
#               'Textiles / Garments / Accessories',
#               'Textiles / Garments / Accessories',
#               'Export / Import',
#               'Textiles / Garments / Accessories',
#               'Textiles / Garments / Accessories',
#               'Textiles / Garments / Accessories',
#               'FMCG / Foods / Beverage',
#               'Recruitment / Staffing',
#               'Courier / Transportation / Freight / Warehousing',
#               'Export / Import',
#               'Textiles / Garments / Accessories',
#               'Printing / Packaging',
#               'Printing / Packaging',
#               'IT-Software / Software Services',
#               'Recruitment / Staffing',
#               'Export / Import'],
#              'IT Software - Systems': ['IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'Banking / Financial Services / Broking',
#               'Internet / Ecommerce',
#               'Banking / Financial Services / Broking',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'Banking / Financial Services / Broking',
#               'Banking / Financial Services / Broking',
#               'IT-Software / Software Services',
#               'Banking / Financial Services / Broking',
#               'Telecom/ISP',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'Courier / Transportation / Freight / Warehousing',
#               'Banking / Financial Services / Broking',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'Telecom/ISP /',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'Telecom/ISP',
#               'Travel / Hotels / Restaurants / Airlines / Railways',
#               'Banking / Financial Services / Broking',
#               'Internet / Ecommerce',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'Industrial Products / Heavy Machinery',
#               'Travel / Hotels / Restaurants / Airlines / Railways',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'IT-Software / Software Services',
#               'Recruitment / Staffing',
#               'Recruitment / Staffing'],
#              'Packaging': ['FMCG / Foods / Beverage',
#               'FMCG / Foods / Beverage',
#               'FMCG / Foods / Beverage',
#               'Internet / Ecommerce',
#               'FMCG / Foods / Beverage',
#               'Recruitment / Staffing',
#               'Pharma / Biotech / Clinical Research',
#               'Pharma / Biotech / Clinical Research'],
#              'Shipping': ['Travel / Hotels / Restaurants / Airlines / Railways']})

# %%
from collections import Counter
def most_frequent(List): 
    occurence_count = Counter(List) 
    return occurence_count.most_common(1)[0][0]

# %%
skill_industry_frequent = {}
for key,value in skill_industry_count.items():
    skill_industry_frequent[key] = most_frequent(value)

# %%
skill_industry_frequent
# Out:
# {'ITES': 'BPO / Call Centre / ITES',
#  'Marketing': 'IT-Software / Software Services',
#  'IT Software - Application Programming': 'IT-Software / Software Services',
#  'Accounts': 'Accounting / Finance',
#  'Production': 'Automobile / Auto Anciliary / Auto Components',
#  'Sales': 'IT-Software / Software Services',
#  'IT Software - Other': 'IT-Software / Software Services',
#  'Executive Assistant': 'IT-Software / Software Services',
#  'IT Software - Mobile': 'IT-Software / Software Services',
#  'Engineering Design': 'Automobile / Auto Anciliary / Auto Components',
#  'Financial Services': 'Banking / Financial Services / Broking',
#  'Hotels': 'Travel / Hotels / Restaurants / Airlines / Railways',
#  'IT Software - QA & Testing': 'IT-Software / Software Services',
#  'HR': 'Recruitment / Staffing',
#  'Supply Chain': 'Automobile / Auto Anciliary / Auto Components',
#  'IT Software - Network Administration': 'IT-Software / Software Services',
#  'Architecture': 'Architecture / Interior Design',
#  'Legal': 'Legal',
#  'Site Engineering': 'Construction / Engineering / Cement / Metals',
#  'Journalism': 'IT-Software / Software Services',
#  nan: 'Other',
#  'IT Software - DBA': 'IT-Software / Software Services',
#  'Strategy': 'IT-Software / Software Services',
#  'Medical': 'Medical / Healthcare / Hospitals',
#  'Design': 'IT-Software / Software Services',
#  'Defence Forces': 'IT-Software / Software Services',
#  'IT Software - Mainframe': 'IT-Software / Software Services',
#  'IT Software - Telecom Software': 'IT-Software / Software Services',
#  'IT Software - Embedded': 'IT-Software / Software Services',
#  'IT Software - Middleware': 'IT-Software / Software Services',
#  'Teaching': 'Education / Teaching / Training',
#  'IT Software - System Programming': 'IT-Software / Software Services',
#  'IT Software - Client/Server Programming': 'IT-Software / Software Services',
#  'Travel': 'Travel / Hotels / Restaurants / Airlines / Railways',
#  'IT Software - eCommerce': 'IT-Software / Software Services',
#  'TV': 'Media / Entertainment / Internet',
#  'Fashion Designing': 'Textiles / Garments / Accessories',
#  'IT Software - ERP': 'IT-Software / Software Services',
#  'IT Hardware': 'IT-Software / Software Services',
#  'Analytics & Business Intelligence': 'IT-Software / Software Services',
#  'Beauty/Fitness/Spa Services': 'Wellness / Fitness / Sports / Beauty',
#  'Top Management': 'IT-Software / Software Services',
#  'Export': 'Export / Import',
#  'IT Software - Systems': 'IT-Software / Software Services',
#  'Packaging': 'FMCG / Foods / Beverage',
#  'Shipping': 'Travel / Hotels / Restaurants / Airlines / Railways'}

# %%
for i in range(len(test)):
    test.loc[i,'industry'] = skill_industry_frequent[test.loc[i, 'skills']]

# %%
test[['Id','industry']].to_csv('frequent_submission.csv', index=False)

# %%
train.head()
# Out:
#    Id                                     company  \
# 0   1                            MM Media Pvt Ltd
# 1   2                          find live infotech
# 2   3         Softtech Career Infosystem Pvt. Ltd
# 3   4                      Onboard HRServices LLP
# 4   5  Spire Technologies and Solutions Pvt. Ltd.
#
#                                            education   experience  \
# 0  UG: B.Tech/B.E. - Any Specialization PG:Any Po...    0 - 1 yrs
# 1  UG: B.Tech/B.E. - Any Specialization PG:MBA/PG...    0 - 0 yrs
# 2  UG: Any Graduate - Any Specialization PG:Any P...    4 - 8 yrs
# 3  UG: Any Graduate - Any Specialization PG:CA Do...  11 - 15 yrs
# 4  UG: B.Tech/B.E. - Any Specialization PG:Any Po...    6 - 8 yrs
#
#                                       jobdescription         jobid  \
# 0  Job Description   Send me Jobs like this Quali...  2.110000e+11
# 1  Job Description   Send me Jobs like this Quali...  2.110000e+11
# 2  Job Description   Send me Jobs like this - as ...  1.010000e+11
# 3  Job Description   Send me Jobs like this - Inv...  8.101690e+10
# 4  Job Description   Send me Jobs like this Pleas...  1.210000e+11
#
#                                  joblocation_address  \
# 0                                            Chennai
# 1                                            Chennai
# 2                                          Bengaluru
# 3  Mumbai, Bengaluru, Kolkata, Chennai, Coimbator...
# 4                                          Bengaluru
#
#                                    jobtitle  numberofpositions  \
# 0  Walkin Data Entry Operator (night Shift)                NaN
# 1        Work Based Onhome Based Part Time.               60.0
# 2                    Pl/sql Developer - SQL                NaN
# 3    Manager/ad/partner - Indirect Tax - CA                NaN
# 4           JAVA Technical Lead (6-8 yrs) -                4.0
#
#                           payrate                   postdate  \
# 0         1,50,000 - 2,25,000 P.A  2016-05-21 19:30:00 +0000
# 1  1,50,000 - 2,50,000 P.A. 20000  2016-05-21 19:30:00 +0000
# 2      Not Disclosed by Recruiter  2016-10-13 16:20:55 +0000
# 3      Not Disclosed by Recruiter  2016-10-13 16:20:55 +0000
# 4      Not Disclosed by Recruiter  2016-10-13 16:20:55 +0000
#
#                                   skills  \
# 0                                   ITES
# 1                              Marketing
# 2  IT Software - Application Programming
# 3                               Accounts
# 4  IT Software - Application Programming
#
#                                    industry
# 0          Media / Entertainment / Internet
# 1  Advertising / PR / MR / Event Management
# 2           IT-Software / Software Services
# 3    Banking / Financial Services / Broking
# 4           IT-Software / Software Services

# %%
train['jobdescription'].head()
# Out:
# 0    Job Description   Send me Jobs like this Quali...
# 1    Job Description   Send me Jobs like this Quali...
# 2    Job Description   Send me Jobs like this - as ...
# 3    Job Description   Send me Jobs like this - Inv...
# 4    Job Description   Send me Jobs like this Pleas...
# Name: jobdescription, dtype: object

# %%
print(len(train['jobdescription']),len(train['jobdescription'].unique()))
# Out:
# 19422 18990

# %%
print(train['jobdescription'][0])
print('--------------------------------------------------------')
print(train['jobdescription'][1000])
# Out:
# Job Description   Send me Jobs like this Qualifications: - == > 10th To Graduation & Any Skill: - == > Basic Computer Knowledge Job Requirement : - == > System or Laptop Type of job: - == > Full Time or Part time Languages : - == > Tamil & English. Experience : - == > Freshers & Experience payment details: - 1 form per day 5/- 10 form per day 50/- 100 form per day 500/- monthly you can earn 15000/- per month Selection Process: - == > Easy Selection Process,So What Are You Waiting For? Apply Now & Grab Best Opportunity To Make Your Carrier & To Improve Your Earing Skills. More detail contact Mr Hari 8678902528 9003010282 Salary:INR 1,50,000 - 2,25,000 P.A Industry: Media / Entertainment / Internet Functional Area: ITES , BPO , KPO , LPO , Customer Service , Operations Role Category:Other Role:Fresher Keyskills English Typing Part Time Data Entry Selection Process Desired Candidate Profile Education- UG: B.Tech/B.E. - Any Specialization PG:Any Postgraduate - Any Specialization, Post Graduation Not Required Please refer to the Job description above Company Profile: MM Media Pvt Ltd Mass Media International Find Live Info Pvt Ltd DATA SERVICES is established in the year 2012 with a vision of transforming an ordinary to extra ordinary thing. Find live info is one of our main project, it is a developing search engine site based at Chennai, India. With years of experience, we have crafted massive data collection job opportunities for public. FIND LIVE INFO a blend of experience, imagination, strategy and action to create digital experience that excite, challenge, inspire and engage users. FIND LIVE INFO provides other business opportunities which will be handled by experts of various fields. We have interesting combination of young and experienced Specialists Under the guidance of our Top Management we bloom towards success More detail contect 8678902528 Download PPT Photo 1   View Contact Details
# --------------------------------------------------------
# Job Description   Send me Jobs like this Job Experience: 2- 5 years of development experience Experience in web based Java applications Must be strong in product Development Experience in using project automation tools a strong plus Experience in the areas of code coverage, unit testing, code quality, build automation Experience with HTML5/ AJAX Should be comfortable with HTML Understanding of indexing and basic DB performance tuning Experience in server side Java tech, using open technologies: hibernate, struts, spring framework etc Should understand MVC and should have worked on some MVC framework, such as struts. Salary: Not Disclosed by Recruiter Industry: IT-Software / Software Services Functional Area: IT Software - Application Programming , Maintenance Role Category:Programming & Design Role:Team Lead/Technical Lead Desired Candidate Profile Education- UG: B.Tech/B.E. PG:Post Graduation Not Required Doctorate:Any Doctorate - Any Specialization, Doctorate Not Required Please refer to the Job description above Company Profile: Next Education India Pvt Ltd Next Education India Pvt Ltd Download PPT Photo 1   View Contact Details

# %%
import re
import nltk
nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to /home/sai-
# [nltk_data]     girish/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /home/sai-girish/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
stop_words = set(stopwords.words('english'))

# %%
def get_job_description_filters(description):
    features = []
    word_tokens = nltk.word_tokenize(description)
    filtered_words = [w for w in word_tokens if not w in stop_words]
    for word in filtered_words:
        features.append(word.lower())
    return features

# %%
description_industry = train[['Id','jobdescription','industry']]
description_industry.head()
# Out:
#    Id                                     jobdescription  \
# 0   1  Job Description   Send me Jobs like this Quali...
# 1   2  Job Description   Send me Jobs like this Quali...
# 2   3  Job Description   Send me Jobs like this - as ...
# 3   4  Job Description   Send me Jobs like this - Inv...
# 4   5  Job Description   Send me Jobs like this Pleas...
#
#                                    industry
# 0          Media / Entertainment / Internet
# 1  Advertising / PR / MR / Event Management
# 2           IT-Software / Software Services
# 3    Banking / Financial Services / Broking
# 4           IT-Software / Software Services

# %%
print(get_job_description_filters(description_industry.loc[0,'jobdescription']))
# Out:
# ['job', 'description', 'send', 'jobs', 'like', 'qualifications', ':', '-', '==', '>', '10th', 'to', 'graduation', '&', 'any', 'skill', ':', '-', '==', '>', 'basic', 'computer', 'knowledge', 'job', 'requirement', ':', '-', '==', '>', 'system', 'laptop', 'type', 'job', ':', '-', '==', '>', 'full', 'time', 'part', 'time', 'languages', ':', '-', '==', '>', 'tamil', '&', 'english', '.', 'experience', ':', '-', '==', '>', 'freshers', '&', 'experience', 'payment', 'details', ':', '-', '1', 'form', 'per', 'day', '5/-', '10', 'form', 'per', 'day', '50/-', '100', 'form', 'per', 'day', '500/-', 'monthly', 'earn', '15000/-', 'per', 'month', 'selection', 'process', ':', '-', '==', '>', 'easy', 'selection', 'process', ',', 'so', 'what', 'are', 'you', 'waiting', 'for', '?', 'apply', 'now', '&', 'grab', 'best', 'opportunity', 'to', 'make', 'your', 'carrier', '&', 'to', 'improve', 'your', 'earing', 'skills', '.', 'more', 'detail', 'contact', 'mr', 'hari', '8678902528', '9003010282', 'salary', ':', 'inr', '1,50,000', '-', '2,25,000', 'p.a', 'industry', ':', 'media', '/', 'entertainment', '/', 'internet', 'functional', 'area', ':', 'ites', ',', 'bpo', ',', 'kpo', ',', 'lpo', ',', 'customer', 'service', ',', 'operations', 'role', 'category', ':', 'other', 'role', ':', 'fresher', 'keyskills', 'english', 'typing', 'part', 'time', 'data', 'entry', 'selection', 'process', 'desired', 'candidate', 'profile', 'education-', 'ug', ':', 'b.tech/b.e', '.', '-', 'any', 'specialization', 'pg', ':', 'any', 'postgraduate', '-', 'any', 'specialization', ',', 'post', 'graduation', 'not', 'required', 'please', 'refer', 'job', 'description', 'company', 'profile', ':', 'mm', 'media', 'pvt', 'ltd', 'mass', 'media', 'international', 'find', 'live', 'info', 'pvt', 'ltd', 'data', 'services', 'established', 'year', '2012', 'vision', 'transforming', 'ordinary', 'extra', 'ordinary', 'thing', '.', 'find', 'live', 'info', 'one', 'main', 'project', ',', 'developing', 'search', 'engine', 'site', 'based', 'chennai', ',', 'india', '.', 'with', 'years', 'experience', ',', 'crafted', 'massive', 'data', 'collection', 'job', 'opportunities', 'public', '.', 'find', 'live', 'info', 'blend', 'experience', ',', 'imagination', ',', 'strategy', 'action', 'create', 'digital', 'experience', 'excite', ',', 'challenge', ',', 'inspire', 'engage', 'users', '.', 'find', 'live', 'info', 'provides', 'business', 'opportunities', 'handled', 'experts', 'various', 'fields', '.', 'we', 'interesting', 'combination', 'young', 'experienced', 'specialists', 'under', 'guidance', 'top', 'management', 'bloom', 'towards', 'success', 'more', 'detail', 'contect', '8678902528', 'download', 'ppt', 'photo', '1', 'view', 'contact', 'details']

# %%
stop_words
# Out:
# {'a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  'her',
#  'here',
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  'if',
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'just',
#  'll',
#  'm',
#  'ma',
#  'me',
#  'mightn',
#  "mightn't",
#  'more',
#  'most',
#  'mustn',
#  "mustn't",
#  'my',
#  'myself',
#  'needn',
#  "needn't",
#  'no',
#  'nor',
#  'not',
#  'now',
#  'o',
#  'of',
#  'off',
#  'on',
#  'once',
#  'only',
#  'or',
#  'other',
#  'our',
#  'ours',
#  'ourselves',
#  'out',
#  'over',
#  'own',
#  're',
#  's',
#  'same',
#  'shan',
#  "shan't",
#  'she',
#  "she's",
#  'should',
#  "should've",
#  'shouldn',
#  "shouldn't",
#  'so',
#  'some',
#  'such',
#  't',
#  'than',
#  'that',
#  "that'll",
#  'the',
#  'their',
#  'theirs',
#  'them',
#  'themselves',
#  'then',
#  'there',
#  'these',
#  'they',
#  'this',
#  'those',
#  'through',
#  'to',
#  'too',
#  'under',
#  'until',
#  'up',
#  've',
#  'very',
#  'was',
#  'wasn',
#  "wasn't",
#  'we',
#  'were',
#  'weren',
#  "weren't",
#  'what',
#  'when',
#  'where',
#  'which',
#  'while',
#  'who',
#  'whom',
#  'why',
#  'will',
#  'with',
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't",
#  'y',
#  'you',
#  "you'd",
#  "you'll",
#  "you're",
#  "you've",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves'}

# %%
len(nltk.word_tokenize(description_industry.loc[0,'jobdescription']))
# Out:
# 354

# %%
print(len(get_job_description_filters(description_industry.loc[0,'jobdescription'])))
# Out:
# 306

# %%
description_industry.head()
# Out:
#    Id                                     jobdescription  \
# 0   1  Job Description   Send me Jobs like this Quali...
# 1   2  Job Description   Send me Jobs like this Quali...
# 2   3  Job Description   Send me Jobs like this - as ...
# 3   4  Job Description   Send me Jobs like this - Inv...
# 4   5  Job Description   Send me Jobs like this Pleas...
#
#                                    industry
# 0          Media / Entertainment / Internet
# 1  Advertising / PR / MR / Event Management
# 2           IT-Software / Software Services
# 3    Banking / Financial Services / Broking
# 4           IT-Software / Software Services

# %% [markdown]
# # Preliminary text exploration
#
# ## Fetch word count for each job description

# %%
description_industry['word_count'] = description_industry['jobdescription'].apply(lambda x : len(str(x).split(" ")))
description_industry[['jobdescription', 'word_count']].head()
# Out:
# /home/sai-girish/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#                                       jobdescription  word_count
# 0  Job Description   Send me Jobs like this Quali...         320
# 1  Job Description   Send me Jobs like this Quali...         248
# 2  Job Description   Send me Jobs like this - as ...         259
# 3  Job Description   Send me Jobs like this - Inv...         427
# 4  Job Description   Send me Jobs like this Pleas...         434

# %%
## Descriptive statistics of word counts
description_industry.word_count.describe()
# Out:
# count    19422.000000
# mean       284.225312
# std        182.732267
# min          1.000000
# 25%        164.000000
# 50%        231.000000
# 75%        347.000000
# max       3223.000000
# Name: word_count, dtype: float64

# %% [markdown]
# The average word count is about 284 words per job description. The word count ranges from a minimum of 1 to a maximum of 3223.

# %% [markdown]
# ## Most common and uncommon words

# %%
job_description_string = ''
for i in range(len(description_industry)):
    job_description_string += str(description_industry.loc[i,'jobdescription']) + ' '

# %%
job_description_string[:2000]
# Out:
# 'Job Description \xa0 Send me Jobs like this Qualifications: - == > 10th To Graduation & Any Skill: - == > Basic Computer Knowledge Job Requirement : - == > System or Laptop Type of job: - == > Full Time or Part time Languages : - == > Tamil & English. Experience : - == > Freshers & Experience payment details: - 1 form per day 5/- 10 form per day 50/- 100 form per day 500/- monthly you can earn 15000/- per month Selection Process: - == > Easy Selection Process,So What Are You Waiting For? Apply Now & Grab Best Opportunity To Make Your Carrier & To Improve Your Earing Skills. More detail contact Mr Hari 8678902528 9003010282 Salary:INR 1,50,000 - 2,25,000 P.A Industry: Media / Entertainment / Internet Functional Area: ITES , BPO , KPO , LPO , Customer Service , Operations Role Category:Other Role:Fresher Keyskills English Typing Part Time Data Entry Selection Process Desired Candidate Profile Education- UG: B.Tech/B.E. - Any Specialization PG:Any Postgraduate - Any Specialization, Post Graduation Not Required Please refer to the Job description above Company Profile: MM Media Pvt Ltd Mass Media International Find Live Info Pvt Ltd DATA SERVICES is established in the year 2012 with a vision of transforming an ordinary to extra ordinary thing. Find live info is one of our main project, it is a developing search engine site based at Chennai, India. With years of experience, we have crafted massive data collection job opportunities for public. FIND LIVE INFO a blend of experience, imagination, strategy and action to create digital experience that excite, challenge, inspire and engage users. FIND LIVE INFO provides other business opportunities which will be handled by experts of various fields. We have interesting combination of young and experienced Specialists Under the guidance of our Top Management we bloom towards success More detail contect 8678902528 Download PPT Photo 1 \xa0 View Contact Details Job Description \xa0 Send me Jobs like this Qualifications: - == > 10th To Grad'

# %%
# Identify common words
freq = pd.Series(job_description_string.split()).value_counts()[:50]
freq
# Out:
# and                182955
# the                106309
# to                 104637
# of                  98366
# in                  83510
# -                   77706
# with                53035
# ,                   46001
# for                 45680
# a                   45236
# /                   44216
# Any                 41972
# Job                 41287
# Not                 39609
# &                   34198
# Doctorate           26192
# on                  26085
# is                  26070
# Required            25840
# by                  23989
# like                23815
# Company             23689
# this                23112
# Jobs                22932
# Description         22714
# Candidate           21829
# Specialization,     21488
# 1                   21151
# experience          20835
# Desired             20557
# Profile             20364
# Contact             20149
# Software            20107
# Functional          20020
# me                  19938
# Profile:            19843
# Details             19748
# Role                19736
# Send                19625
# View                19620
# Industry:           19427
# Photo               19422
# Area:               19415
# PPT                 19373
# Download            19364
# be                  18946
# Education-          18174
# UG:                 18041
# as                  17761
# or                  16072
# dtype: int64

# %%
#Identify uncommon words
freq1 = pd.Series(job_description_string.split()).value_counts()[-50:]
freq1
# Out:
# HRIS-a                            1
# interview.Since                   1
# SOI,                              1
# !In                               1
# Standardisation                   1
# Specialization:                   1
# (workshops                        1
# ITC-WelcomGroup,                  1
# Role:International                1
# Fruits&                           1
# OrderManagement.                  1
# budgeting)                        1
# Email:sudha.k@focusite.com        1
# microfinance                      1
# downstream),Power                 1
# inflection                        1
# standards/guidelines              1
# ecomexpress.in                    1
# LRS                               1
# processor:                        1
# Gr                                1
# together&amp;quot;                1
# Codebrahma.                       1
# onsite).                          1
# analysis,bom,dc,procedures',      1
# terry.                            1
# swathi@recruiseindia.com,         1
# TBB,                              1
# YOGAM!Whats                       1
# HTML/HTML5.0                      1
# scenarioscases                    1
# meetings•                         1
# Result-oriented,                  1
# manager/Counter                   1
# ALE/IDoc                          1
# month-on-month.                   1
# Arrangements,                     1
# expendable                        1
# (ABCTCL).                         1
# ,ADO.Net-Entity                   1
# (DSA/Alliances/others)*Meeting    1
# Npower,                           1
# Newsprint                         1
# content.raquoAdministering        1
# subsidies.                        1
# FE)                               1
# Apportioning                      1
# '021215500744',                   1
# Executive-(BPO                    1
# EURC                              1
# dtype: int64

# %% [markdown]
# ## Text Pre-processing

# %%
# Libraries for text preprocessing
import re
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from nltk.tokenize import RegexpTokenizer
nltk.download('wordnet') 
from nltk.stem.wordnet import WordNetLemmatizer
# Out:
# [nltk_data] Downloading package stopwords to /home/sai-
# [nltk_data]     girish/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /home/sai-
# [nltk_data]     girish/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
##Creating a list of stop words and adding custom stopwords
stop_words = set(stopwords.words("english"))
##Creating a list of custom stopwords
new_words = ["using", "show", "result", "large", "also", "iv", "one", "two", "new", "previously", "shown"]
stop_words = stop_words.union(new_words)

# %%
corpus = []
for i in range(len(description_industry)):
    #Remove punctuations
    text = re.sub('[^a-zA-Z]', ' ', str(description_industry['jobdescription'][i]))
    
    #Convert to lowercase
    text = text.lower()
    
    #remove tags
    text=re.sub("&lt;/?.*?&gt;"," &lt;&gt; ",text)
    
    # remove special characters and digits
    text=re.sub("(\\d|\\W)+"," ",text)
    
    ##Convert to list from string
    text = text.split()
    
    ##Stemming
    ps=PorterStemmer()
    #Lemmatisation
    lem = WordNetLemmatizer()
    text = [lem.lemmatize(word) for word in text if not word in  
            stop_words] 
    text = " ".join(text)
    corpus.append(text)

# %%
#View corpus item
corpus[222]
# Out:
# 'job description send job like experience year role mainframe pm job location bangalore chennai role description responsible development implementation application mainframe technology responsible build deployment support application identified resource need constant verbal written contact key stakeholder peer india u ensure compliance standard best practice development including change management release management source code control perform call duty rotation basis maintain support production code required document perform disaster recovery exercise candidate description posse good knowledge cics cobol db vsam jcl good cics system knowledge would valuable good understanding cics dynamic transaction routing process familiar db tool file aid scheduler debugger tool good communication ability interact partner good presentation interpersonal skill exposure brokerage finance domain added advantage skill knowledge experience familiarity mainframe technology cics cobol db vsam jcl must least year industry experience experienced industry standard test management tool java plus bachelor degree required behavioural attribute high level commitment initiative vision enthusiasm creative energetic assertive hand professional enjoys challenge change salary disclosed recruiter industry software software service functional area software mainframe role category project management role project manager software keyskills change management release management build desired candidate profile please refer job description education ug graduate specialization pg postgraduate specialization company profile recruise u based firm download ppt photo view contact detail'

# %% [markdown]
# ## Data Exploration

# %%
import sys
print(sys.executable)
# Out:
# /home/sai-girish/anaconda3/bin/python

# %%
#Word cloud
from os import path
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import matplotlib.pyplot as plt
wordcloud = WordCloud(
                          background_color='white',
                          stopwords=stop_words,
                          max_words=100,
                          max_font_size=50, 
                          random_state=42
                         ).generate(str(corpus))
print(wordcloud)
fig = plt.figure(1)
plt.imshow(wordcloud)
plt.axis('off')
plt.show()
fig.savefig("word1.png", dpi=900)
# Out:
# <wordcloud.wordcloud.WordCloud object at 0x7f6ab0d9a2d0>

# %% [markdown]
# # Text preparation
#
#
# ## Creating a vector of word counts

# %%
from sklearn.feature_extraction.text import CountVectorizer
import re
cv=CountVectorizer(max_df=0.8,stop_words=stop_words, max_features=10000, ngram_range=(1,3))
X=cv.fit_transform(corpus)

# %%
list(cv.vocabulary_.keys())[:10]
# Out:
# ['qualification',
#  'th',
#  'graduation',
#  'skill',
#  'basic',
#  'computer',
#  'knowledge',
#  'requirement',
#  'system',
#  'laptop']

# %% [markdown]
# ## Visualize top N uni-grams, bi-grams & tri-grams

# %%
#Most frequently occuring words
def get_top_n_words(corpus, n=None):
    vec = CountVectorizer().fit(corpus)
    bag_of_words = vec.transform(corpus)
    sum_words = bag_of_words.sum(axis=0) 
    words_freq = [(word, sum_words[0, idx]) for word, idx in      
                   vec.vocabulary_.items()]
    words_freq =sorted(words_freq, key = lambda x: x[1], 
                       reverse=True)
    return words_freq[:n]
#Convert most freq words to dataframe for plotting bar plot
top_words = get_top_n_words(corpus, n=20)
top_df = pd.DataFrame(top_words)
top_df.columns=["Word", "Freq"]
#Barplot of most freq words
import seaborn as sns
sns.set(rc={'figure.figsize':(13,8)})
g = sns.barplot(x="Word", y="Freq", data=top_df)
g.set_xticklabels(g.get_xticklabels(), rotation=30)
# Out:
# [Text(0, 0, 'job'),
#  Text(0, 0, 'doctorate'),
#  Text(0, 0, 'role'),
#  Text(0, 0, 'profile'),
#  Text(0, 0, 'software'),
#  Text(0, 0, 'experience'),
#  Text(0, 0, 'description'),
#  Text(0, 0, 'service'),
#  Text(0, 0, 'company'),
#  Text(0, 0, 'required'),
#  Text(0, 0, 'specialization'),
#  Text(0, 0, 'candidate'),
#  Text(0, 0, 'industry'),
#  Text(0, 0, 'business'),
#  Text(0, 0, 'skill'),
#  Text(0, 0, 'development'),
#  Text(0, 0, 'like'),
#  Text(0, 0, 'area'),
#  Text(0, 0, 'detail'),
#  Text(0, 0, 'design')]

# %%
#Most frequently occuring Bi-grams
def get_top_n2_words(corpus, n=None):
    vec1 = CountVectorizer(ngram_range=(2,2),  
            max_features=2000).fit(corpus)
    bag_of_words = vec1.transform(corpus)
    sum_words = bag_of_words.sum(axis=0) 
    words_freq = [(word, sum_words[0, idx]) for word, idx in     
                  vec1.vocabulary_.items()]
    words_freq =sorted(words_freq, key = lambda x: x[1], 
                reverse=True)
    return words_freq[:n]
top2_words = get_top_n2_words(corpus, n=20)
top2_df = pd.DataFrame(top2_words)
top2_df.columns=["Bi-gram", "Freq"]
print(top2_df)
#Barplot of most freq Bi-grams
import seaborn as sns
sns.set(rc={'figure.figsize':(13,8)})
h=sns.barplot(x="Bi-gram", y="Freq", data=top2_df)
h.set_xticklabels(h.get_xticklabels(), rotation=45)
# Out:
#                      Bi-gram   Freq
# 0            job description  37595
# 1          candidate profile  19816
# 2          desired candidate  19702
# 3            functional area  19626
# 4            company profile  19511
# 5             contact detail  19441
# 6                   job like  19430
# 7           description send  19424
# 8                   send job  19423
# 9               download ppt  19357
# 10                 ppt photo  19357
# 11                photo view  19357
# 12              view contact  19357
# 13             role category  18897
# 14              education ug  18060
# 15       doctorate doctorate  15944
# 16  specialization doctorate  15771
# 17        doctorate required  15713
# 18         profile education  15599
# 19        recruiter industry  14468
# [Text(0, 0, 'job description'),
#  Text(0, 0, 'candidate profile'),
#  Text(0, 0, 'desired candidate'),
#  Text(0, 0, 'functional area'),
#  Text(0, 0, 'company profile'),
#  Text(0, 0, 'contact detail'),
#  Text(0, 0, 'job like'),
#  Text(0, 0, 'description send'),
#  Text(0, 0, 'send job'),
#  Text(0, 0, 'download ppt'),
#  Text(0, 0, 'ppt photo'),
#  Text(0, 0, 'photo view'),
#  Text(0, 0, 'view contact'),
#  Text(0, 0, 'role category'),
#  Text(0, 0, 'education ug'),
#  Text(0, 0, 'doctorate doctorate'),
#  Text(0, 0, 'specialization doctorate'),
#  Text(0, 0, 'doctorate required'),
#  Text(0, 0, 'profile education'),
#  Text(0, 0, 'recruiter industry')]

# %%
#Most frequently occuring Tri-grams
def get_top_n3_words(corpus, n=None):
    vec1 = CountVectorizer(ngram_range=(3,3), 
           max_features=2000).fit(corpus)
    bag_of_words = vec1.transform(corpus)
    sum_words = bag_of_words.sum(axis=0) 
    words_freq = [(word, sum_words[0, idx]) for word, idx in     
                  vec1.vocabulary_.items()]
    words_freq =sorted(words_freq, key = lambda x: x[1], 
                reverse=True)
    return words_freq[:n]
top3_words = get_top_n3_words(corpus, n=20)
top3_df = pd.DataFrame(top3_words)
top3_df.columns=["Tri-gram", "Freq"]
print(top3_df)
#Barplot of most freq Tri-grams
import seaborn as sns
sns.set(rc={'figure.figsize':(13,8)})
j=sns.barplot(x="Tri-gram", y="Freq", data=top3_df)
j.set_xticklabels(j.get_xticklabels(), rotation=45)
# Out:
#                               Tri-gram   Freq
# 0            desired candidate profile  19650
# 1                 job description send  19424
# 2                        send job like  19423
# 3                 description send job  19422
# 4                   download ppt photo  19357
# 5                       ppt photo view  19357
# 6                   photo view contact  19357
# 7                  view contact detail  19357
# 8          candidate profile education  15595
# 9                 profile education ug  15525
# 10        disclosed recruiter industry  14467
# 11          salary disclosed recruiter  14464
# 12               refer job description  13673
# 13                    please refer job  13668
# 14  doctorate doctorate specialization  13166
# 15   specialization doctorate required  12955
# 16  doctorate specialization doctorate  12875
# 17             job description company  11924
# 18         description company profile  11908
# 19               required please refer  10811
# [Text(0, 0, 'desired candidate profile'),
#  Text(0, 0, 'job description send'),
#  Text(0, 0, 'send job like'),
#  Text(0, 0, 'description send job'),
#  Text(0, 0, 'download ppt photo'),
#  Text(0, 0, 'ppt photo view'),
#  Text(0, 0, 'photo view contact'),
#  Text(0, 0, 'view contact detail'),
#  Text(0, 0, 'candidate profile education'),
#  Text(0, 0, 'profile education ug'),
#  Text(0, 0, 'disclosed recruiter industry'),
#  Text(0, 0, 'salary disclosed recruiter'),
#  Text(0, 0, 'refer job description'),
#  Text(0, 0, 'please refer job'),
#  Text(0, 0, 'doctorate doctorate specialization'),
#  Text(0, 0, 'specialization doctorate required'),
#  Text(0, 0, 'doctorate specialization doctorate'),
#  Text(0, 0, 'job description company'),
#  Text(0, 0, 'description company profile'),
#  Text(0, 0, 'required please refer')]

# %% [markdown]
# ## Converting to a matrix of integers

# %%
from sklearn.feature_extraction.text import TfidfTransformer
 
tfidf_transformer=TfidfTransformer(smooth_idf=True,use_idf=True)
tfidf_transformer.fit(X)
# get feature names
feature_names=cv.get_feature_names()
 
# fetch document for which keywords needs to be extracted
doc=corpus[530]
 
#generate tf-idf for the given document
tf_idf_vector=tfidf_transformer.transform(cv.transform([doc]))

# %%
#Function for sorting tf_idf in descending order
from scipy.sparse import coo_matrix
def sort_coo(coo_matrix):
    tuples = zip(coo_matrix.col, coo_matrix.data)
    return sorted(tuples, key=lambda x: (x[1], x[0]), reverse=True)
 
def extract_topn_from_vector(feature_names, sorted_items, topn=10):
    """get the feature names and tf-idf score of top n items"""
    
    #use only topn items from vector
    sorted_items = sorted_items[:topn]
 
    score_vals = []
    feature_vals = []
    
    # word index and corresponding tf-idf score
    for idx, score in sorted_items:
        
        #keep track of feature name and its corresponding score
        score_vals.append(round(score, 3))
        feature_vals.append(feature_names[idx])
 
    #create a tuples of feature,score
    #results = zip(feature_vals,score_vals)
    results= {}
    for idx in range(len(feature_vals)):
        results[feature_vals[idx]]=score_vals[idx]
    
    return results
#sort the tf-idf vectors by descending order of scores
sorted_items=sort_coo(tf_idf_vector.tocoo())
#extract only the top n; n here is 10
keywords=extract_topn_from_vector(feature_names,sorted_items,5)
 
# now print the results
print("\nAbstract:")
print(doc)
print("\nKeywords:")
for k in keywords:
    print(k,keywords[k])
# Out:
# Abstract:
# job description send job like warm greeting scaleneworks people solution llp huge opening hcl processor screening co ordination role criterion exp year year sourcing screening co ordination good communication handle screening boarding client handling follow candidate escalation handling sla adherence follow delivery team effectively schedule facilitate interview client hcl scaleneworks payroll ctc lpa lpa open position bangalore chennai pune salary disclosed recruiter industry recruitment staffing functional area hr recruitment administration ir role category hr recruitment ir role recruitment executive keyskills sourcing scheduling coordination hr executive interview scheduling interview coordination screening profile screening desired candidate profile education ug graduate specialization company profile confidential confidential download ppt photo view contact detail
#
# Keywords:
# screening 0.441
# lpa 0.192
# recruitment 0.184
# interview 0.178
# hcl 0.176

# %%
0.8*len(corpus)/10
# Out:
# 1553.76

# %%
train[train['industry'].isnull()].index.tolist()
# Out:
# [2767, 3025, 3144, 16000]

# %%
train.loc[2767,'industry'] = 'Not Specified'
train.loc[3025,'industry'] = 'Not Specified'
train.loc[3144,'industry'] = 'Not Specified'
train.loc[16000,'industry'] = 'Not Specified'

# %%
X_train = corpus[:1553]
X_test = corpus[1553:]
y_train = train.loc[:1553,'industry']
y_test = train.loc[1553:,'industry']

# %%
print(len(corpus), len(train), len(X_train), len(X_test), len(y_train), len(y_test))
# Out:
# 19422 19422 1553 17869 1554 17869

# %%
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer = TfidfVectorizer()
train_vectors = vectorizer.fit_transform(X_train)
test_vectors = vectorizer.transform(X_test)
print(train_vectors.shape, test_vectors.shape)
# Out:
# (1553, 12038) (17869, 12038)

# %%
from sklearn.naive_bayes import MultinomialNB
clf = MultinomialNB().fit(train_vectors, y_train[:1553])

# %%
from  sklearn.metrics  import accuracy_score
predicted = clf.predict(test_vectors)
print(accuracy_score(y_test,predicted))
# Out:
# 0.4393642621299457

# %%
print(y_test.isnull().sum())
# Out:
# 0

# %%
train['industry'].isnull().sum()
# Out:
# 0

# %%
from sklearn import svm
clf_svm = svm.SVC().fit(train_vectors, y_train[:1553])
predicted_svm = clf_svm.predict(test_vectors)
print(accuracy_score(y_test, predicted_svm))
# Out:
# 0.5562146734568246

# %%
from sklearn.ensemble import RandomForestClassifier
clf_rfc = RandomForestClassifier(n_estimators=18).fit(train_vectors, y_train[:1553])
predicted_rfc = clf_rfc.predict(test_vectors)
print(accuracy_score(y_test, predicted_rfc))
# Out:
# 0.6691476859365382

# %%
from sklearn.metrics import f1_score
f1_score(y_test, predicted_rfc, average='micro')
# Out:
# 0.6691476859365382

# %%
from sklearn.ensemble import GradientBoostingClassifier
clf_gbc = GradientBoostingClassifier(random_state=10).fit(train_vectors, y_train[:1553])
predicted_gbc = clf_gbc.predict(test_vectors)
f1_score(y_test, predicted_gbc, average='micro')
# Out:
# 0.8144272203257037

# %%
from sklearn.ensemble import AdaBoostClassifier
clf_abc = AdaBoostClassifier(n_estimators=100, random_state=0).fit(train_vectors, y_train[:1553])
predicted_abc = clf_abc.predict(test_vectors)
f1_score(y_test, predicted_abc, average='micro')
# Out:
# 0.5108847725110527

# %%
predicted_rfc
# Out:
# array(['IT-Software / Software Services',
#        'IT-Software / Software Services',
#        'Construction / Engineering / Cement / Metals', ...,
#        'IT-Software / Software Services',
#        'IT-Software / Software Services',
#        'IT-Software / Software Services'], dtype=object)

# %%
corpus_rfc = []
for i in range(len(test)):
    #Remove punctuations
    text = re.sub('[^a-zA-Z]', ' ', str(test['jobdescription'][i]))
    
    #Convert to lowercase
    text = text.lower()
    
    #remove tags
    text=re.sub("&lt;/?.*?&gt;"," &lt;&gt; ",text)
    
    # remove special characters and digits
    text=re.sub("(\\d|\\W)+"," ",text)
    
    ##Convert to list from string
    text = text.split()
    
    ##Stemming
    ps=PorterStemmer()
    #Lemmatisation
    lem = WordNetLemmatizer()
    text = [lem.lemmatize(word) for word in text if not word in  
            stop_words] 
    text = " ".join(text)
    corpus_rfc.append(text)

# %%
print(len(corpus_rfc), len(test))
# Out:
# 2577 2577

# %%
X_true_test = corpus_rfc
true_test_vectors = vectorizer.transform(X_true_test)

# %%
predicted_test_rfc = clf_rfc.predict(true_test_vectors)
print(len(predicted_test_rfc), predicted_test_rfc[:2])
# Out:
# 2577 ['Education / Teaching / Training' 'IT-Software / Software Services']

# %%
submission_r = pd.read_csv('sample_submission.csv')

# %%
print(len(submission_r))
# Out:
# 2577

# %%
for i in range(len(submission_r)):
    submission_r.loc[i,'industry'] = predicted_test_rfc[i]

# %%
submission_r.head()
# Out:
#       Id                         industry
# 0  19423  Education / Teaching / Training
# 1  19424  IT-Software / Software Services
# 2  19425  IT-Software / Software Services
# 3  19426  IT-Software / Software Services
# 4  19427           Recruitment / Staffing

# %%
submission_r.to_csv('submission_r_2.csv', index=False)

# %%
submission_g = pd.read_csv('sample_submission.csv')

# %%
print(len(submission_g))
# Out:
# 2577

# %%
predicted_test_gbc = clf_gbc.predict(true_test_vectors)
print(len(predicted_test_gbc), predicted_test_gbc[:2])
# Out:
# 2577 ['Education / Teaching / Training' 'FMCG / Foods / Beverage']

# %%
for i in range(len(submission_g)):
    submission_g.loc[i,'industry'] = predicted_test_gbc[i]

# %%
submission_g.head()
# Out:
#       Id                         industry
# 0  19423  Education / Teaching / Training
# 1  19424          FMCG / Foods / Beverage
# 2  19425  IT-Software / Software Services
# 3  19426  IT-Software / Software Services
# 4  19427           Recruitment / Staffing

# %%
submission_g.to_csv('submission_g.csv', index=False)
